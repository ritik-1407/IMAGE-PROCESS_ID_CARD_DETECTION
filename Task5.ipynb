# %%
# %pip install tesseract
# Out:
# Collecting tesseract
#   Downloading tesseract-0.1.3.tar.gz (45.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 MB 17.5 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: tesseract
#   Building wheel for tesseract (setup.py) ... done
#   Created wheel for tesseract: filename=tesseract-0.1.3-py3-none-any.whl size=45562552 sha256=dc7161be7e04f7565f8197e0026ce5e3150800eb1652ae46c836726ca0062113
#   Stored in directory: /Users/ritikgupta/Library/Caches/pip/wheels/71/c9/aa/698c579693e83fdda9ad6d6f0d8f61ed986e27925ef576f109
# Successfully built tesseract
# Installing collected packages: tesseract
# Successfully installed tesseract-0.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=21.3 in /Users/ritikgupta/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages (from pytesseract) (23.0)
# Requirement already satisfied: Pillow>=8.0.0 in /Users/ritikgupta/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages (from pytesseract) (10.2.0)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytesseract

# %%
image_folder = '/Users/ritikgupta/Downloads/5_ocr/5_ocr/'

# %%
import pytesseract
from PIL import Image

# Install pytesseract using pip if not already installed
# pip install pytesseract

# Install Tesseract OCR engine: https://github.com/tesseract-ocr/tesseract
# Make sure to add the Tesseract installation directory to your system PATH

def extract_text_from_image(image_path):
    # Open the image using PIL (Python Imaging Library)
    image = Image.open(image_path)

    # Perform OCR using pytesseract
    text = pytesseract.image_to_string(image)

    return text

# %%
import os
import matplotlib.pyplot as plt
for filename in os.listdir(image_folder):
    if filename.endswith(('.jpg', '.jpeg', '.png')):
        image_path = os.path.join(image_folder, filename)
        recognized_text = extract_text_from_image(image_path)
        img = plt.imread(image_path)
        plt.imshow(img)
        plt.show()

        print("Recognized Text =====================/n")
        print(recognized_text)
        break
# Out:
# Recognized Text =====================/n
# BLAU 29365 SPRAKENSEHL
# 144 CM KONIGSBERGER STRASSE 93
#
# 08.09.2014
#
# BURGERMEISTERAMT
# ETTLINGEN
#
# TFION7NW52<<BUERGERK<KAFRAK<K <<< KKK << KKK KK KKK
#
# IDD<<TFION?NW523<<< << <<< KKK
# 9304099<2409076DK<<<<<sssss<<s<5
# BUERGER<<AFRA<<<<<<<<cssssssss

# %%
def Recognized_Text(image):
        recognized_text = extract_text_from_image(image)
        print("Recognized Text =====================/n")
        print(recognized_text)
        return recognized_text
